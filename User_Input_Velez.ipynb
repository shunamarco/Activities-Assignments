# %%
person_name = ""
person_age = 0

print("Student Activity\nBasic User Input Program")

person_name = input("\nPlease enter your name:\n")
person_age = input("Enter your age:\n")

print("Hi!", person_name, "Remember to always stay positive.")
print("Nice to know that you are", person_age, "years old.")
# Out:
# Student Activity
# Basic User Input Program
#
# Please enter your name:
# Gege
# Enter your age:
# Yawa
# Hi! Gege Remember to always stay positive.
# Nice to know that you are Yawa years old.
